# %% [markdown]
# # **<p style="text-align:center;">  <span style="color:white;">Flask Project Made by Ahmed Basiony</span></p>**

# %% [markdown]
#  ## <span style="color:orange">*Order Management project using Flask and SQL Server, with optional HTML integration*</span>

# %% [markdown]
# # <span style="color:red">Create a database called InventoryDB. </span>
# 1- Customers (Pre-loaded from API) .
#
# CREATE TABLE Customers (
#
# customer_id INT PRIMARY KEY,
#
# full_name NVARCHAR(100),
#
# email NVARCHAR(100),
#
# city NVARCHAR(50));

# %%
import pandas as pd
import pyodbc
from flask import Flask, render_template, redirect , request, url_for
from pathlib import Path
import requests

# %%
### crate database called InventoryDB
conn = pyodbc.connect('Driver={SQL Server};'
                    'Server=.\\SQLEXPRESS;'
                    'Database=mydata;'
                    'Trusted_Connection=yes;')


cursor = conn.cursor()
cursor.execute("CREATE DATABASE InventoryDB;")
cursor.commit()
cursor.close()
conn.close()

# %%
### connect to database called InventoryDB
conn = pyodbc.connect('Driver={SQL Server};'
                    'Server=.\\SQLEXPRESS;'
                    'Database=InventoryDB;'
                    'Trusted_Connection=yes;')
cursor = conn.cursor()
### create table called Customers
cursor.execute("""CREATE TABLE Customers 
                (customer_id INT PRIMARY KEY, 
                full_name NVARCHAR(100),
                email NVARCHAR(100),
                city NVARCHAR(50));"""
                )
cursor.commit()

# %% [markdown]
# # <span style="color:red">Create a database called InventoryDB. </span>
# 2- Products (Pre-loaded from API)
#
# CREATE TABLE Products (
#
# product_id INT PRIMARY KEY,
#
# name NVARCHAR(100),
#
# price DECIMAL(10,2),
#
# stock_quantity INT)

# %%
### create table called Products
cursor.execute("""CREATe TABLE Products
                ( product_id INT PRIMARY KEY,
                product_name NVARCHAR(100),
                price DECIMAL(10, 2), 
                quantity INT);"""
                )

# %% [markdown]
# # <span style="color:red">Create a database called InventoryDB. </span>
# 3- Orders Table
#
# CREATE TABLE Orders (
#
# order_id INT PRIMARY KEY IDENTITY(1,1),
#
# customer_id INT NOT NULL,
#
# product_id INT NOT NULL,
#
# quantity INT NOT NULL,
#
# price DECIMAL(10,2) NOT NULL,
#
# order_date DATETIME DEFAULT GETDATE(),
#
# status NVARCHAR(20) DEFAULT 'Pending',
#
# FOREIGN KEY (customer_id) REFERENCES Customers(customer_id),
#
# FOREIGN KEY (product_id) REFERENCES Products(product_id));

# %%
### create table called Orders
cursor.execute("""
                CREATE TABLE Orders
                (order_id INT PRIMARY KEY IDENTITY(1,1), 
                customer_id INT, 
                product_id INT, 
                order_date DATETIME DEFAULT GETDATE(),
                Status NVARCHAR(20) DEFAULT 'Pending', 
                FOREIGN KEY (customer_id) REFERENCES Customers(customer_id), 
                FOREIGN KEY (product_id) REFERENCES Products(product_id));
                """)
cursor.commit()
cursor.close()
conn.close()

# %% [markdown]
#  ### <span style="color:orange">*After creating the database and tables using Python to connect to SQL Server and your database, use the Requests library to download the data of employees and products from the following APIs and insert them into the tables*</span>

# %%
### getting data of customers and products
response = requests.get("https://raw.githubusercontent.com/MohammedHameds/Flask-project/refs/heads/main/dataset/customers.json")
customers = pd.DataFrame(response.json())
response = requests.get("https://raw.githubusercontent.com/MohammedHameds/Flask-project/refs/heads/main/dataset/products.json")
products = pd.DataFrame(response.json())

# %% [markdown]
# # <span style="color:red">Insert the data into the database. </span>

# %%
con = pyodbc.connect('Driver={SQL Server};'
                    'Server=.\\SQLEXPRESS;'
                    'Database=InventoryDB;'
                    'Trusted_Connection=yes;')
cursor = con.cursor()
cursor.fast_executemany = True

cursor.executemany(
    "INSERT INTO Customers VALUES (?, ?, ?, ?)",
    customers.values.tolist()
)
con.commit()

cursor.executemany(
    "INSERT INTO Products VALUES (?, ?, ?, ?)",
    products.values.tolist()
)
con.commit()

cursor.close()

# %% [markdown]
#  ### <span style="color:orange">*Now that the database is ready, let's create a Flask app that includes some methods.*</span>

# %% [markdown]
# # <span style="color:red">1- Create Order Method: POST - Endpoint: “/orders” </span>
# # <span style="color:red">2- Dsiplay Orders Method: GET Endpoint: /allorders</span>
# # <span style="color:red">3- Get Order Details Method: GET Endpoint: /orders/<order_id> </span>

# %%
from flask import Flask, render_template, request, redirect, url_for, session
from pathlib import Path
import pyodbc

# -----------------------------
# Paths
# -----------------------------
BASE_DIR = Path.cwd().parent
TEMPLATES_DIR = BASE_DIR / "templates"
STATIC_DIR = BASE_DIR / "static"

app = Flask(__name__, template_folder=str(TEMPLATES_DIR), static_folder=str(STATIC_DIR))
app.secret_key = "any_secret_key"


# -----------------------------
# Database Connection
# -----------------------------
def get_conn():
    return pyodbc.connect(
        "Driver={SQL Server};"
        "Server=.\\SQLEXPRESS;"
        "Database=InventoryDB;"
        "Trusted_Connection=yes;"
    )


# -----------------------------
# Routes
# -----------------------------
@app.route("/")
def home():
    return render_template("index.html")


@app.route("/login", methods=["GET", "POST"])
def login():
    if request.method == "POST":
        email = request.form.get("email", "").strip()

        conn = get_conn()
        cur = conn.cursor()
        cur.execute(
            "SELECT customer_id, full_name FROM Customers WHERE email = ?", (email,)
        )
        user = cur.fetchone()
        conn.close()

        if user:
            session["customer_id"] = int(user[0])
            session["customer_name"] = user[1]
            return redirect(url_for("home"))

        return render_template("login.html", error="Email not found")

    # GET
    return render_template("login.html")


@app.route("/logout")
def logout():
    session.clear()
    return redirect(url_for("home"))


@app.route("/add-order", methods=["POST"])
def add_order():
    customer_id = session.get("customer_id")
    if not customer_id:
        return redirect(url_for("login"))

    product_id = int(request.form["product_id"])

    conn = get_conn()
    cur = conn.cursor()

    try:
        
        cur.execute("""
            UPDATE Products
            SET quantity = quantity - 1
            WHERE product_id = ? AND quantity > 0
        """,(product_id,))

        
        if cur.rowcount == 0:
            conn.rollback()
            return "Out of stock", 400


        cur.execute("""
            INSERT INTO Orders (customer_id, product_id, order_date)
            VALUES (?, ?, GETDATE())
        """, (customer_id, product_id))

        conn.commit()
        return redirect(url_for("display_orders"))

    except Exception as e:
        conn.rollback()
        raise e

    finally:
        conn.close()


@app.route("/all_orders")
def display_orders():
    conn = get_conn()
    cur = conn.cursor()

    cur.execute(
        """
                SELECT
                o.order_id,
                o.order_date,
                c.full_name,
                p.product_name,
                p.price
                FROM Orders o
                JOIN Customers c ON c.customer_id = o.customer_id
                JOIN Products p ON p.product_id = o.product_id
                ORDER BY o.order_id DESC
        """
    )

    rows = cur.fetchall()
    conn.close()

    orders = [
        {
            "order_id": r[0],
            "order_date": r[1],
            "customer_name": r[2],
            "product_name": r[3],
            "price": float(r[4]),
        }
        for r in rows
    ]

    return render_template("display_orders.html", orders=orders)


@app.route("/orders/<int:order_id>")
def get_order_details(order_id):
    return render_template("get_order_details.html", order_id=order_id)


# -----------------------------
# Run App
# -----------------------------
if __name__ == "__main__":
    app.run(port=5050, debug=True, use_reloader=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:
"GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 02:44:58] "GET /static/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:44:58] "GET /static/images/logo.png HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:44:58] "GET /static/images/home%20page%20Photo.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:44:58] "GET /static/images/T1.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:44:58] "GET /static/images/online-shopping.png HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:44:58] "GET /static/images/iphone%2014.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:44:58] "GET /static/images/samsung-55.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:44:58] "GET /static/images/Mouse.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:45:15] "POST /login HTTP/1.1" 302 -
# 127.0.0.1 - - [22/Feb/2026 02:45:15] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 02:45:15] "GET /static/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:45:15] "GET /static/images/home%20page%20Photo.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:45:15] "GET /static/images/logo.png HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:45:15] "GET /static/images/T1.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:45:15] "GET /static/images/online-shopping.png HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:45:15] "GET /static/images/iphone%2014.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:45:15] "GET /static/images/samsung-55.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:45:15] "GET /static/images/Mouse.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:46:13] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 02:46:13] "GET /static/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:46:13] "GET /static/images/T1.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:46:13] "GET /static/images/home%20page%20Photo.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:46:13] "GET /static/images/logo.png HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:46:13] "GET /static/images/online-shopping.png HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:46:13] "GET /static/images/iphone%2014.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:46:13] "GET /static/images/samsung-55.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:46:13] "GET /static/images/Mouse.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:47:07] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 02:47:07] "GET /static/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:47:07] "GET /static/images/home%20page%20Photo.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:47:07] "GET /static/images/T1.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:47:07] "GET /static/images/logo.png HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:47:07] "GET /static/images/online-shopping.png HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:47:07] "GET /static/images/iphone%2014.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:47:07] "GET /static/images/samsung-55.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:47:07] "GET /static/images/Mouse.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:47:19] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 02:47:19] "GET /static/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:47:19] "GET /static/images/logo.png HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:47:19] "GET /static/images/home%20page%20Photo.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:47:19] "GET /static/images/T1.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:47:19] "GET /static/images/online-shopping.png HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:47:19] "GET /static/images/iphone%2014.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:47:19] "GET /static/images/samsung-55.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:47:19] "GET /static/images/Mouse.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:47:31] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 02:47:31] "GET /static/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:47:31] "GET /static/images/home%20page%20Photo.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:47:31] "GET /static/images/logo.png HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:47:31] "GET /static/images/T1.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:47:31] "GET /static/images/online-shopping.png HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:47:31] "GET /static/images/iphone%2014.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:47:31] "GET /static/images/samsung-55.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:47:31] "GET /static/images/Mouse.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:47:55] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 02:47:56] "GET /static/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:47:56] "GET /static/images/T1.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:47:56] "GET /static/images/logo.png HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:47:56] "GET /static/images/home%20page%20Photo.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:47:56] "GET /static/images/online-shopping.png HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:47:56] "GET /static/images/iphone%2014.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:47:56] "GET /static/images/samsung-55.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:47:56] "GET /static/images/Mouse.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:49:04] "GET /logout HTTP/1.1" 302 -
# 127.0.0.1 - - [22/Feb/2026 02:49:04] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 02:49:04] "GET /static/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:49:04] "GET /static/images/T1.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:49:04] "GET /static/images/home%20page%20Photo.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:49:04] "GET /static/images/logo.png HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:49:04] "GET /static/images/iphone%2014.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:49:04] "GET /static/images/online-shopping.png HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:49:04] "GET /static/images/samsung-55.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:49:04] "GET /static/images/Mouse.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:49:04] "GET /login HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 02:49:04] "GET /static/Loginstyle.css HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 02:49:05] "GET /static/images/Login.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:49:30] "GET /login HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 02:49:30] "GET /static/Loginstyle.css HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 02:49:30] "GET /static/images/Login.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:49:38] "GET /login HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 02:49:38] "GET /static/Loginstyle.css HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 02:49:38] "GET /static/images/Login.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:49:44] "GET /login HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 02:49:44] "GET /static/Loginstyle.css HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 02:49:44] "GET /static/images/Login.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:50:09] "GET /login HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 02:50:09] "GET /static/Loginstyle.css HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 02:50:09] "GET /static/images/Login.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:50:17] "GET /login HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 02:50:17] "GET /static/Loginstyle.css HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 02:50:17] "GET /static/images/Login.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:50:24] "GET /login HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 02:50:24] "GET /static/Loginstyle.css HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 02:50:24] "GET /static/images/Login.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:50:29] "GET /login HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 02:50:29] "GET /static/Loginstyle.css HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 02:50:29] "GET /static/images/Login.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:50:50] "GET /login HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 02:50:50] "GET /static/Loginstyle.css HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 02:50:50] "GET /static/images/Login.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:51:07] "GET /login HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 02:51:07] "GET /static/Loginstyle.css HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 02:51:07] "GET /static/images/Login.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:51:14] "GET /login HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 02:51:14] "GET /static/Loginstyle.css HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 02:51:14] "GET /static/images/Login.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:51:21] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 02:51:21] "GET /static/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:51:21] "GET /static/images/home%20page%20Photo.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:51:21] "GET /static/images/logo.png HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:51:21] "GET /static/images/T1.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:51:21] "GET /static/images/online-shopping.png HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:51:21] "GET /static/images/iphone%2014.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02:51:21] "GET /static/images/samsung-55.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 02
"GET /all_orders HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 03:52:34] "GET /all_orders HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "C:\Users\Basio_Wolf\AppData\Roaming\Python\Python314\site-packages\flask\app.py", line 1536, in __call__
#     return self.wsgi_app(environ, start_response)
#            ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Basio_Wolf\AppData\Roaming\Python\Python314\site-packages\flask\app.py", line 1514, in wsgi_app
#     response = self.handle_exception(e)
#   File "C:\Users\Basio_Wolf\AppData\Roaming\Python\Python314\site-packages\flask\app.py", line 1511, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Basio_Wolf\AppData\Roaming\Python\Python314\site-packages\flask\app.py", line 919, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Basio_Wolf\AppData\Roaming\Python\Python314\site-packages\flask\app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Basio_Wolf\AppData\Roaming\Python\Python314\site-packages\flask\app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "C:\Users\Basio_Wolf\AppData\Local\Temp\ipykernel_7864\2562268120.py", line 141, in display_orders
#     return render_template("display_orders.html", orders=orders)
#   File "C:\Users\Basio_Wolf\AppData\Roaming\Python\Python314\site-packages\flask\templating.py", line 150, in render_template
#     return _render(app, template, context)
#   File "C:\Users\Basio_Wolf\AppData\Roaming\Python\Python314\site-packages\flask\templating.py", line 131, in _render
#     rv = template.render(context)
#   File "C:\Users\Basio_Wolf\AppData\Roaming\Python\Python314\site-packages\jinja2\environment.py", line 1295, in render
#     self.environment.handle_exception()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\Basio_Wolf\AppData\Roaming\Python\Python314\site-packages\jinja2\environment.py", line 942, in handle_exception
#     raise rewrite_traceback_stack(source=source)
#   File "d:\Github\Flask_project\templates\display_orders.html", line 18, in top-level template code
#     #{{ o.order_id }} {{ o.order_date }}
#   File "C:\Users\Basio_Wolf\AppData\Roaming\Python\Python314\site-packages\jinja2\environment.py", line 490, in getattr
#     return getattr(obj, attribute)
# jinja2.exceptions.UndefinedError: 'o' is undefined
# 127.0.0.1 - - [22/Feb/2026 03:52:34] "GET /all_orders?__debugger__=yes&cmd=resource&f=style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 03:52:34] "GET /all_orders?__debugger__=yes&cmd=resource&f=debugger.js HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 03:52:34] "GET /all_orders?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 03:52:34] "GET /all_orders?__debugger__=yes&cmd=resource&f=console.png&s=8sbrwSbo0g9cOvFGggyK HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 03:52:47] "GET /all_orders HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 03:53:17] "GET /all_orders HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 03:55:22] "GET /all_orders HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 03:55:22] "GET /static/DisplayOrdersStyle.css HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 03:55:22] "GET /static/images/Login.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 03:55:40] "GET /all_orders HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 03:55:40] "GET /static/DisplayOrdersStyle.css HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 03:58:20] "GET /login HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 03:58:25] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 03:58:25] "GET /static/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 03:58:25] "GET /static/images/home%20page%20Photo.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 03:58:25] "GET /static/images/logo.png HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 03:58:25] "GET /static/images/T1.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 03:58:25] "GET /static/images/online-shopping.png HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 03:58:25] "GET /static/images/iphone%2014.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 03:58:25] "GET /static/images/samsung-55.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 03:58:25] "GET /static/images/Mouse.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 03:58:25] "GET /static/images/Keyboard.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 03:58:25] "GET /static/images/Printer.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 03:58:25] "GET /static/images/Background.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 03:58:25] "GET /static/images/External%20driver.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 03:58:25] "GET /static/images/Headset.png HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 03:58:51] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 03:58:51] "GET /static/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 03:58:51] "GET /static/images/iphone%2014.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 03:58:51] "GET /static/images/online-shopping.png HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 03:58:51] "GET /static/images/T1.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 03:58:51] "GET /static/images/logo.png HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 03:58:51] "GET /static/images/home%20page%20Photo.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 03:58:51] "GET /static/images/samsung-55.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 03:58:51] "GET /static/images/Mouse.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 03:58:51] "GET /static/images/Keyboard.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 03:58:51] "GET /static/images/Printer.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 03:58:51] "GET /static/images/External%20driver.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 03:58:51] "GET /static/images/Headset.png HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 03:58:51] "GET /static/images/Login.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 03:59:16] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2026 03:59:16] "GET /static/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 03:59:16] "GET /static/images/logo.png HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 03:59:16] "GET /static/images/home%20page%20Photo.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 03:59:16] "GET /static/images/T1.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 03:59:16] "GET /static/images/online-shopping.png HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 03:59:16] "GET /static/images/iphone%2014.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 03:59:16] "GET /static/images/samsung-55.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 03:59:16] "GET /static/images/Mouse.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2026 03